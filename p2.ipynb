# %%
print("hello")
# Out:
# hello

# %%
a='10'
print(type(a))
# Out:
# <class 'str'>

# %%
gift_price = 2000
my_money = 1000
borrowed_money = 1000
total_amount = my_money + borrowed_money

if total_amount >= gift_price:
    print("Can purchase the gift")
else:
    print("Cannot purchase the gift")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 gift_price = 2000
# ----> 2 my_money = int(input("Enter your money: "))
#       3 borrowed_money = int(input("Enter the money borrowed from your friend: "))
#       4 total_amount = my_money + borrowed_money
#       5
#
# ValueError: invalid literal for int() with base 10: ''
